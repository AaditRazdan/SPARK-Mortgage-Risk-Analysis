# %% [markdown]
# <h1>Explore Credit Score Analysis for Mortgage Risk   </h1>

# %% [markdown]
# <h4>Import Python Libraries </h4>
# <h5>
#     1) Pandas - A powerful data analysis and manipulation library. Backbone of data science in Python since it can perform statistics and aggregations<br>
#     2) Matplotlib - Essentially the "drawing engine" of Python. Many visual representations can be made - line plots, bar charts, histograms, and scatter plots among others<br>
#     3) Seaborn - It is essentially an extension of Matplotlib, it is designed to make visual representations cleaner and easier to create (fewer lines of code)<br>
#     4) Sklearn - An open-source library that provides tools for supervised learning (ex: regression), unsupervised learning (ex: clustering), data preprocessing (ex: scaling) and other functions <br>
# </h5>

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# %% [markdown]
# <h4>Read the source file and assign column names </h4>
# <h5>
#     1) This data was downloaded from the Freddie Mac loan website <br>
#     2) This data is an annual standard loan-level dataset from 2021 <br>
#     3) The URL for this website is the following: https://www.freddiemac.com/research/datasets/sf-loanlevel-dataset <br>
#     4) The table below shows all of the drivers that are extracted from the file. Examples include: credit score, cltv_score and others
# </h5>

# %%
# Read the data file and assign column names and display first 10 rows
source_df = pd.read_csv("data/sample_orig_2021.txt", delimiter = "|")
source_df.columns = ['credit_score','first_payment_date','first_time_homebuyer_flag','maturity_date','msa','mortgage_insurance_percentage',
                     'num_units','occupancy_status','cltv_score','dti','upb','ltv','interest_rate','channel','ppm_flag','amortization_type','state',
                     'property_type','postal_code','loan_sequence_number','loan_purpose','loan_term','num_borrowers','seller_name',
                     'servicer_name','super_conforming_flag','loan_sequence_number','p_indicator','harp_indicator','pvm','io_indicator',
                     'mortgage_ins_cancel_indicator'
]
display(source_df.head(10))

# %% [markdown]
# <h4>Create a histogram that shows the distribution of Credit Scores </h4>
# <h5> as a side note, FICO scores and Credit Scores are the same thing</h5><br>
# <h5>
#     1) plt.figure line codes the size of the graph of the histogram <br>
#     2) the source_df line creates a histogram that has a size of 30, ranges from 300-850, color is steel blue, and the edge color is black for aesthetic reasons <br>
#     3) the subsequent lines code the x-axis, y-axis, title <br>
#     4) the final lines simply show the graph
# </h5>

# %%
# Histogram of FICO Scores
plt.figure(figsize = (10,6))
source_df['credit_score'].hist(bins = 30, range = (300, 850), color = 'steelblue', edgecolor = 'black')
plt.title('Distribution of Credit Scores')
plt.xlabel('Credit Score')
plt.ylabel('Count')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>Result: For the 2021 data sample, most of the credit scores range ~ 750-800</h4>
# <h4>This indicates that the borrowers can be classified as low-risk (could get lower interest rates, easier to qualify for credit cards)</h4>

# %% [markdown]
# <h4>Display a data table that only shows relevant columns </h4>
# <h5>
#     I simply reused my code from earlier, except the selected_columns line is to only look at the specified columns. <br>
#     Notice: some of the rows have NaN - this is a mistake and needs to be resolved.
# </h5>

# %%
# Retain the columns required for the analysis and display first 10 rows
selected_columns = ['credit_score', 'cltv_score','occupancy_status', 'dti', 'loan_purpose', 'state', 'first_time_homebuyer_flag', 'mortgage_insurance_percentage', 'interest_rate', 'num_units', 'property_type', 'upb']
selected_df = source_df[selected_columns]
display(selected_df.head(10))

# %% [markdown]
# <h4>Get rid of unrealistic or extraneous data </h4>
# <h5>
#     The NaN that was there in the previous data table is not here anymore
# </h5>

# %%
# Drop rows where 'credit_score' is less than 350 or more than 850
credit_filtered_df = selected_df[(selected_df['credit_score'] >= 350) & (selected_df['credit_score'] <= 850)]

# Drop rows where 'occupency_rate' or 'cltv_score' are null
final_df = credit_filtered_df.dropna(subset=['occupancy_status', 'cltv_score'])

display(final_df.head(10))

# %% [markdown]
# <h4>Create a scatterplot based on the fully revised data table that measures Credit Score vs CLTV Score by Occupancy Rate </h4>
# <h5>
#     1) plt.figure codes the graph that the scatterplot occupies <br>
#     2) The subsequent lines below code for the various aspects of the scatter plot (x-axis, y-axis, color, transparency, etc) <br>
#     P - Primary Residence <br>
#     I - Investment Property <br>
#     S - Second Home
# </h5>

# %%
# Create the scatter plot
plt.figure(figsize = (12, 6))
sns.scatterplot(
    data = final_df,
    x = 'credit_score',
    y = 'cltv_score',
    hue = 'occupancy_status',
    palette = 'viridis',
    s = 100, # Adjust marker size
    alpha = 1.0 # Adjust transparency
)

plt.title('Credit Score vs. CLTV Score by Occupancy Status')
plt.xlabel('Credit Score')
plt.ylabel('CLTV Score')
plt.grid(True, linestyle = '--', alpha = 0.6)
plt.legend(title = 'Occupancy Status') 
plt.show()

# %% [markdown]
# <h4>For context, we are mainly looking for green dots because that indicates a high percentage of available spaces are currently being used. A low occupancy rate means that a high percentage of availabel spaces are vacant. In addition, we want to look for borrowers that have a high credit score and low CLTV score. </h4>
# <h4>Result: While there are lots of data points, one thing is clear. Just because a borrower has a high credit score does not mean that they have a low CLTV score. CLTV is a financial metric used to assess the risk associated with a mortgage loan. Even though a high FICO score means the borrower has good creditworthiness, if that borrower has a high CLTV score, it suggests a significant amount of debt on the property relative to its value - concerning lenders </h4>

# %% [markdown]
# <h4>Create a box plot that plots Original CLTV by Loan Purpose</h4>
# <h5>
#     *This box plot compares the loan-to-value risk based on why the loan was taken*<br>
#     1) plt.figure line codes the graph that the box plot occupies <br>
#     2) the elements of the creation of the box plot is on the next lines <br>
#     3) next, the elements of the graph itself are on the next lines <br> P - Purchase <br> C - Refinance (Cash out) <br> N - Refinance (No cash out)
#
#
# </h5>

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(
    data = final_df,
    x = 'loan_purpose', 
    y = 'cltv_score',
    hue = 'loan_purpose',
    palette = 'Pastel1',
    legend= False
)
plt.title('CLTV by Loan Purpose')
plt.xlabel('Loan Purpose')
plt.ylabel('Original CLTV')
plt.grid(True, linestyle = '--', alpha = 0.5)
plt.xticks(rotation = 30)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>Result: Refinance loans (no cash out) generally have lower and more consistent Original CLTVs compared to refinance loans (cash out) and Construction-to-Permanent loans which exhibit higher median CLTVs and thus more variability.  </h4>

# %% [markdown]
# <h4>Create a scatter plot that plots Original debt-to-income ratio vs credit score</h4>
# <h5>
#     Essentially, we are comparing income burden vs borrower reliability <br>
#     This scatter plot will tell us whether borrowers with high DTI ratios tend to have higher or lower credit scores - however, it is very clustered. <br> The first section creates the elements of the graph and the second section creates the title, x-axis, y-axis, and others.
#
# </h5>

# %%
plt.figure(figsize = (10, 6))
sns.scatterplot(
    data = final_df,
    x = 'dti',
    y = 'credit_score', 
    alpha = 0.7,
    s = 30,
    color = 'royalblue'
)

plt.title('DTI vs Credit Score (Income Burden vs Borrower Reliability)')
plt.xlabel('Debt-to-Income Ratio (DTI)')
plt.ylabel('Credit Score')
plt.grid(True, linestyle = '--', alpha = 0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>The scatter plot is way too clustered. Create a hexbin which reduces cluster and a better way to visualize dense scatter plots. (Alternate version of scatter plot)</h4>
# <h5>
#     Before creating the hexbin, I filtered out unrealistic values. <br> Then the next lines of code creates the graph and elements of it.
# </h5>

# %%
filtered_df = source_df[
    (source_df['dti'] < 80) & 
    (source_df['credit_score'] < 900) &
    (source_df['credit_score'] > 300)
]
plt.figure(figsize = (10, 6))
plt.hexbin(
    x = filtered_df['dti'],
    y = filtered_df['credit_score'],
    gridsize = 40,
    cmap = 'Blues',
    mincnt = 1
)

plt.colorbar(label = 'Number of Loans')
plt.xlabel('DTI (Debt-To-Income Ratio)')
plt.ylabel('Credit Score')
plt.title('DTI vs Credit Score (Filtered)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4>Result: The higher the DTI of the borrower, the higher their credit score is. In general</h4>
# <h4>This is significant because banks will view those with a high DTI and high credit score as a high-risk borrower because of their high debt-load. Despite the high credit, banks may still refuse to give someone loans if their DTI is high. </h4>

# %% [markdown]
# <h4>Create a bar plot that shows which state have the most borrowers</h4>
# <h5>
#     Kind of like the last graph, it's good to know where the borrowers reside in because then the applications of my research can be designated in certain states rather than the entire country
# </h5>

# %%
borrowers_by_state = final_df['state'].value_counts().head(15)
plt.figure(figsize = (12,7))
sns.barplot(x = borrowers_by_state.values, y = borrowers_by_state.index, palette = 'viridis')
plt.title('Top 15 States by Number of Borrowers')
plt.xlabel('Number of Borrowers')
plt.ylabel('State')
plt.show()

# %% [markdown]
# <h4>Result: Vast majority of the borrowers in the 2021 data sample are Californians</h4><h4>Notable amount of borrowers in Florida and Texas as well</h4>
# <h4> This graph helps me better understand the borrowers in this data sample and also the states that have the most amount of borrowers in this data sample. When my research concludes in October, my work in this project could potentially be implemented in CA, TX, or FL instead of CO or other states because the majority of the borrowers (and thus where the potential problems are located) are mainly in 3 states. Helps with coordination and efficency because different states are in different places.</h4>

# %% [markdown]
# <h4> Create a pie chart to see how many borrowers are first-time homebuyers</h4>
# <h5>
#     It's good to understand the actual borrowers in the data (loan borrowers in 2021)<br>
#     These lines of code generates the bar graph. N - no, Y - yes. obviously
# </h5>

# %%
first_time_counts = final_df['first_time_homebuyer_flag'].value_counts()

labels = first_time_counts.index.map({'Y': 'Yes', 'N': 'No'})
sizes = first_time_counts.values
colors = ['#66c2a5', '#fc8d62'] # this is an optional custom color palette

fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(
    sizes,
    labels = labels,
    autopct = '%1.1f%%',
    startangle = 90,
    colors = colors,
    wedgeprops = dict(width = 0.4)
)

ax.set(aspect = 'equal', title = 'First-Time Homebuyer Breakdown')
plt.show()

# %% [markdown]
# <h4>Result: Most borrowers from the 2021 data sample are NOT first-time homebuyers</h4>
# <h4>Just like other graphs, this helps me understand the borrowers in this data sample and this helps with further analysis and inferring information about the borrowers I wouldn't be able to know without this pie chart.</h4>

# %% [markdown]
# <h4> Create a choropleth that shows the average credit score in all 50 states</h4>

# %%
# this computes average credit score per state

state_credit_scores = final_df.groupby('state')['credit_score'].mean().reset_index()
state_credit_scores.columns = ['state', 'avg_credit_score']

# this plots the map

fig = px.choropleth(
    state_credit_scores,
    locations = 'state',
    locationmode = 'USA-states',
    color = 'avg_credit_score',
    scope = 'usa',
    color_continuous_scale = 'Viridis',
    title = 'Average Credit Score by State'
)
fig.show()

# %% [markdown]
# <h4>Notable: My very first prediction-based model (where it doesn't just code data - it makes a conclusion based off of it). This barplot analyzes the importance of various drivers in the 2021 data sample for determining the risk of a loan. On that note, this graph alone took me several hours and a lot of crashing out. This model is not finished yet.</h4>

# %%
# This calculates property value and risk labels. A high risk loan exceeds 90%
#final_df['property_value'] = final_df['cltv_score'] / 100 * final_df['upb']
#final_df['cltv_percent'] = (final_df['cltv_score'] / final_df['property_value']) * 100
final_df['high_risk'] = final_df['cltv_score'] > 90

# This clips unreasonable dti and credit scores
final_df['dti'] = final_df['dti'].clip(upper=100)
final_df['credit_score'] = final_df['credit_score'].clip(upper=900)

# This is the list of drivers I am analyzing. Currently trying to understand why some of them are not showing up. 
features = [
    'credit_score', 'dti', 'occupancy_status', 'interest_rate', 'num_units',
    'channel', 'seller_name', 'loan_term', 'loan_type', 'upb'
]

# This is feature engineering and target extraction 
features = [col for col in features if col in final_df.columns]
x = final_df[features].copy().fillna(-1)
#x[categorical_cols] = x[categorical_cols].fillna('Missing')
y = final_df.loc[x.index, 'high_risk']

# This identifies categorical columns for encoding
categorical_cols = [col for col in ['channel', 'loan_type', 'seller_name', 'occupancy_status', 'loan_term'] if col in x.columns]
x_encoded = pd.get_dummies(x, columns = categorical_cols)

# Train test split - this is for model evaluation
x_train, x_test, y_train, y_test = train_test_split(x_encoded, y, test_size = 0.3, random_state = 42)

# This trains the model - a RandomForestCLassifier
clf = RandomForestClassifier(class_weight = 'balanced', random_state = 42)
clf.fit(x_train, y_train)

# This is feature importance extraction
importances = clf.feature_importances_
importance_df = pd.DataFrame({
    'feature': x_encoded.columns,
    'importance': clf.feature_importances_
})

importance_df['base_feature'] = importance_df['feature'].str.extract(r'^([^_]+)', expand = False)

# Grouped feature importance aggregation
grouped_importance = (
    importance_df
    .groupby('base_feature')['importance']
    .sum()
    .reset_index()
    .sort_values(by = 'importance', ascending = False)
    .head(20)
)

# This graphs the actual plot
plt.figure(figsize = (10,8))
sns.barplot(data = grouped_importance, x = 'importance', y = 'base_feature', palette = 'viridis')
plt.title('Top Feature Importances (High-Risk Loan Prediction)')
plt.xlabel('Total Importance')
plt.ylabel('Feature')
#plt.xlim(0, importance_df['importance'].max() + 0.01)
plt.tight_layout()
plt.show()

# %%
#for col in ['property_type', 'upb']:
#    if col in selected_df.columns and col not in final_df.columns:
#        final_df[col] = selected_df[col]

# %%
plt.figure(figsize = (12,6))

sns.barplot(
    data = final_df,
    x = 'loan_purpose', 
    y = 'dti',
    hue = 'high_risk',
    palette = 'Set2'
)

plt.title('DTI Distribution by Loan Purpose (Colored by High-Risk Status)')
plt.xlabel('Loan Purpose')
plt.ylabel('Debt-to-Income Ratio (%)')
plt.xticks(rotation = 45)
plt.legend(title = 'High Risk')
plt.tight_layout()
plt.show()

# %%
# This clarifies why there is no true bar for the Cash-out refinance loans
final_df.groupby(['loan_purpose', 'high_risk']).size().unstack(fill_value=0)

# %%
regression_features = [
    'credit_score', 'dti', 'occupancy_status', 'loan_purpose', 'cltv_score',
    'mortgage_insurance_percentage', 'num_units', 'upb', 'loan_term', 'state',
    'channel', 'seller_name', 'property_type'
]

regression_features = [col for col in regression_features if col in final_df.columns]
x_reg = final_df[regression_features].copy()
y_reg = final_df['interest_rate']

categorical_reg_cols = x_reg.select_dtypes(include = 'object').columns.tolist()
x_encoded = pd.get_dummies(x_reg, columns = categorical_reg_cols).fillna(-1)

x_train, x_test, y_train, y_test = train_test_split(
    x_encoded, y_reg, test_size = 0.3, random_state = 42
)

reg = RandomForestRegressor(random_state = 42)
reg.fit(x_train, y_train)

y_pred = reg.predict(x_test)

print(f"R² score: {r2_score(y_test, y_pred):.3f}")
print(f"MAE: {mean_absolute_error(y_test, y_pred):.3f}")

plt.figure(figsize = (8, 6))
sns.scatterplot(x = y_test, y = y_pred, alpha = 0.4)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel('Actual Interest Rate')
plt.ylabel('Predicted Interest Rate')
plt.title('Actual vs Predicted Interest Rate')
plt.tight_layout()
plt.show()
